# %%
import pandas as pd

# %%
df = pd.read_csv('../models/checkpoints/leaderboard.csv')

# %%
df.sort_values('eer', ascending=True).head(10)
# Out:
#      epoch  global_batch  accuracy       eer  \
# 38       1         43000  0.982507  0.016475
# 49       1         64000  0.982544  0.016513
# 95       1        113000  0.984580  0.016645
# 131      2        150000  0.985372  0.016664
# 143      2        162000  0.985598  0.016702
# 120      1        138000  0.985636  0.016796
# 116      1        134000  0.985070  0.016796
# 144      2        163000  0.985146  0.016815
# 117      1        135000  0.985127  0.016815
# 145      2        164000  0.985485  0.016833
#
#                                               filename
# 38   checkpoints/ckpt_epoch1_batch43000_acc0.9825_e...
# 49   checkpoints/ckpt_epoch1_batch64000_acc0.9825_e...
# 95   checkpoints/ckpt_epoch1_batch113000_acc0.9846_...
# 131  checkpoints/ckpt_epoch2_batch150000_acc0.9854_...
# 143  checkpoints/ckpt_epoch2_batch162000_acc0.9856_...
# 120  checkpoints/ckpt_epoch1_batch138000_acc0.9856_...
# 116  checkpoints/ckpt_epoch1_batch134000_acc0.9851_...
# ...

# %%
df.sort_values('accuracy', ascending=False).head(10)
# Out:
#      epoch  global_batch  accuracy       eer  \
# 120      1        138000  0.985636  0.016796
# 138      2        157000  0.985617  0.017173
# 143      2        162000  0.985598  0.016702
# 142      2        161000  0.985542  0.017097
# 145      2        164000  0.985485  0.016833
# 148      2        167000  0.985447  0.016909
# 175      2        194000  0.985429  0.017286
# 139      2        158000  0.985410  0.017135
# 359      3        379000  0.985372  0.017588
# 196      2        215000  0.985372  0.017135
#
#                                               filename
# 120  checkpoints/ckpt_epoch1_batch138000_acc0.9856_...
# 138  checkpoints/ckpt_epoch2_batch157000_acc0.9856_...
# 143  checkpoints/ckpt_epoch2_batch162000_acc0.9856_...
# 142  checkpoints/ckpt_epoch2_batch161000_acc0.9855_...
# 145  checkpoints/ckpt_epoch2_batch164000_acc0.9855_...
# 148  checkpoints/ckpt_epoch2_batch167000_acc0.9854_...
# 175  checkpoints/ckpt_epoch2_batch194000_acc0.9854_...
# ...

# %%
df[df.global_batch == 43000].filename.item()
# Out:
# 'checkpoints/ckpt_epoch1_batch43000_acc0.9825_eer0.0165.ckpt'
